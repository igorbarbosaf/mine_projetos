# %%
import random

numero_secreto = random.randint(1, 10)

tentativas = 0
limite = 3

while tentativas < limite:

    palpite = int(input("Digite um número: "))

    if palpite == numero_secreto:
        print(f"Parabéns! Você acertou, o número secreto é: {numero_secreto} ")
        break

    elif palpite < numero_secreto:
        print("O número é menor")

    elif palpite > numero_secreto:
        print("O número é maior")

    else:
        tentativas += 1
        print("Você errou o número! Tente novamente.")

    if tentativas == limite:
        print("Você atingiu o limite! O número secreto é:", numero_secreto)
# Out:
# O número é maior
# O número é maior
# O número é maior
# O número é maior
# O número é maior
# O número é maior
# O número é menor
# O número é maior
# O número é maior
# O número é maior
# O número é maior
# O número é maior
# O número é maior
# O número é menor
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       6 limite = 3
#       8 while tentativas < limite:
# ---> 10     palpite = int(input("Digite um número: "))
#      12     if palpite == numero_secreto:
#      13         print(f"Parabéns! Você acertou, o número secreto é: {numero_secreto} ")
#
# ValueError: invalid literal for int() with base 10: ''
