# %%
import random

def jogar():

    numero_secreto = random.randint(1, 50)

    tentativas = 0 # Contador começa
    limite = 5 # Limite vai até 5

    # Enquanto tentativas for menor que limite
    while tentativas < limite:

        # Imprime quantas tentativa restante faltam
        print(f"Tentativa {tentativas + 1} de {limite}")

        # Tratamento de erro
        try:

            secreto = int(input("Digite um número: "))

        # Verificando se o usuário não digitou nada além de números inteiros, caso sim dar Erro
        except ValueError:
            print("Por favor! Digite apenas números.")
            continue
        
        if secreto == numero_secreto:
            print("Parabéns! Você acertou o número", numero_secreto)
            break
        
        else:
            tentativas += 1

            if secreto > numero_secreto:
                print("O número é menor.")
            else:
                print("O número é maior.")

    if tentativas == limite:
        print("Você perdeu! O número era:", numero_secreto) 

jogar()
# Out:
# Tentativa 1 de 5
# O número é maior.
# Tentativa 2 de 5
# O número é menor.
# Tentativa 3 de 5
# O número é maior.
# Tentativa 4 de 5
# O número é menor.
# Tentativa 5 de 5
# O número é maior.
# Você perdeu! O número era: 40
